# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
import getpass

from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
loader = CSVLoader(file_path="/Users/ashwin/Applications/PassionProjects/Experiments/command-center/data/job-automation.csv")
data = loader.load()

# %%
text_splitter = CharacterTextSplitter(chunk_size=1500, chunk_overlap=0)
docs = text_splitter.split_documents(data)
# Out:
# Created a chunk of size 1879, which is longer than the specified 1500
# Created a chunk of size 2883, which is longer than the specified 1500
# Created a chunk of size 1531, which is longer than the specified 1500
# Created a chunk of size 1974, which is longer than the specified 1500
# Created a chunk of size 1974, which is longer than the specified 1500
# Created a chunk of size 1604, which is longer than the specified 1500
# Created a chunk of size 1597, which is longer than the specified 1500
# Created a chunk of size 2235, which is longer than the specified 1500
# Created a chunk of size 2591, which is longer than the specified 1500
# Created a chunk of size 1557, which is longer than the specified 1500
# Created a chunk of size 1701, which is longer than the specified 1500
# Created a chunk of size 1596, which is longer than the specified 1500
# Created a chunk of size 1695, which is longer than the specified 1500
# Created a chunk of size 2596, which is longer than the specified 1500
# Created a chunk of size 2596, which is longer than the specified 1500
# Created a chunk of size 2617, which is longer than the specified 1500
# Created a chunk of size 2425, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2424, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 2426, which is longer than the specified 1500
# Created a chunk of size 2424, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2427, which is longer than the specified 1500
# Created a chunk of size 2429, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 2428, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 2427, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2427, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 2428, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2427, which is longer than the specified 1500
# Created a chunk of size 2428, which is longer than the specified 1500
# Created a chunk of size 2425, which is longer than the specified 1500
# Created a chunk of size 2428, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2424, which is longer than the specified 1500
# Created a chunk of size 2428, which is longer than the specified 1500
# Created a chunk of size 2425, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 2429, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2427, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 2425, which is longer than the specified 1500
# Created a chunk of size 2425, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2429, which is longer than the specified 1500
# Created a chunk of size 2426, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 1623, which is longer than the specified 1500
# Created a chunk of size 1817, which is longer than the specified 1500
# Created a chunk of size 1982, which is longer than the specified 1500
# Created a chunk of size 2425, which is longer than the specified 1500
# Created a chunk of size 1712, which is longer than the specified 1500
# Created a chunk of size 1564, which is longer than the specified 1500
# Created a chunk of size 2207, which is longer than the specified 1500
# Created a chunk of size 1517, which is longer than the specified 1500
# Created a chunk of size 1550, which is longer than the specified 1500
# Created a chunk of size 2426, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 3026, which is longer than the specified 1500
# Created a chunk of size 2567, which is longer than the specified 1500
# Created a chunk of size 1768, which is longer than the specified 1500
# Created a chunk of size 1506, which is longer than the specified 1500
# Created a chunk of size 2027, which is longer than the specified 1500
# Created a chunk of size 2027, which is longer than the specified 1500
# Created a chunk of size 1991, which is longer than the specified 1500
# Created a chunk of size 1629, which is longer than the specified 1500
# Created a chunk of size 2732, which is longer than the specified 1500
# Created a chunk of size 2431, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 2426, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 1760, which is longer than the specified 1500
# Created a chunk of size 2431, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 1796, which is longer than the specified 1500
# Created a chunk of size 1909, which is longer than the specified 1500
# Created a chunk of size 1526, which is longer than the specified 1500
# Created a chunk of size 1664, which is longer than the specified 1500
# Created a chunk of size 1966, which is longer than the specified 1500
# Created a chunk of size 2077, which is longer than the specified 1500
# Created a chunk of size 1535, which is longer than the specified 1500
# Created a chunk of size 2160, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 2160, which is longer than the specified 1500
# Created a chunk of size 1777, which is longer than the specified 1500
# Created a chunk of size 1854, which is longer than the specified 1500
# Created a chunk of size 1520, which is longer than the specified 1500
# Created a chunk of size 1549, which is longer than the specified 1500
# Created a chunk of size 1528, which is longer than the specified 1500
# Created a chunk of size 1851, which is longer than the specified 1500
# Created a chunk of size 1635, which is longer than the specified 1500
# Created a chunk of size 1581, which is longer than the specified 1500
# Created a chunk of size 2139, which is longer than the specified 1500
# Created a chunk of size 2427, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 1555, which is longer than the specified 1500
# Created a chunk of size 1635, which is longer than the specified 1500
# Created a chunk of size 2713, which is longer than the specified 1500
# Created a chunk of size 1951, which is longer than the specified 1500
# Created a chunk of size 1580, which is longer than the specified 1500
# Created a chunk of size 1575, which is longer than the specified 1500
# Created a chunk of size 1625, which is longer than the specified 1500
# Created a chunk of size 2205, which is longer than the specified 1500
# Created a chunk of size 1853, which is longer than the specified 1500
# Created a chunk of size 1541, which is longer than the specified 1500
# Created a chunk of size 1552, which is longer than the specified 1500
# Created a chunk of size 1566, which is longer than the specified 1500
# Created a chunk of size 1667, which is longer than the specified 1500
# Created a chunk of size 2037, which is longer than the specified 1500
# Created a chunk of size 1822, which is longer than the specified 1500
# Created a chunk of size 1561, which is longer than the specified 1500
# Created a chunk of size 1696, which is longer than the specified 1500
# Created a chunk of size 1890, which is longer than the specified 1500
# Created a chunk of size 1669, which is longer than the specified 1500
# Created a chunk of size 1839, which is longer than the specified 1500
# Created a chunk of size 1878, which is longer than the specified 1500
# Created a chunk of size 1681, which is longer than the specified 1500
# Created a chunk of size 2727, which is longer than the specified 1500
# Created a chunk of size 1694, which is longer than the specified 1500
# Created a chunk of size 1578, which is longer than the specified 1500
# Created a chunk of size 1696, which is longer than the specified 1500
# Created a chunk of size 1560, which is longer than the specified 1500
# Created a chunk of size 1800, which is longer than the specified 1500
# Created a chunk of size 3583, which is longer than the specified 1500
# Created a chunk of size 1917, which is longer than the specified 1500
# Created a chunk of size 1523, which is longer than the specified 1500
# Created a chunk of size 1991, which is longer than the specified 1500
# Created a chunk of size 1594, which is longer than the specified 1500
# Created a chunk of size 1598, which is longer than the specified 1500
# Created a chunk of size 1525, which is longer than the specified 1500
# Created a chunk of size 1551, which is longer than the specified 1500
# Created a chunk of size 3680, which is longer than the specified 1500
# Created a chunk of size 1648, which is longer than the specified 1500
# Created a chunk of size 1831, which is longer than the specified 1500
# Created a chunk of size 1867, which is longer than the specified 1500
# Created a chunk of size 1688, which is longer than the specified 1500
# Created a chunk of size 1772, which is longer than the specified 1500
# Created a chunk of size 1755, which is longer than the specified 1500
# Created a chunk of size 1522, which is longer than the specified 1500
# Created a chunk of size 1518, which is longer than the specified 1500
# Created a chunk of size 1636, which is longer than the specified 1500
# Created a chunk of size 1662, which is longer than the specified 1500
# Created a chunk of size 1679, which is longer than the specified 1500
# Created a chunk of size 1778, which is longer than the specified 1500
# Created a chunk of size 1578, which is longer than the specified 1500
# Created a chunk of size 1587, which is longer than the specified 1500
# Created a chunk of size 1578, which is longer than the specified 1500
# Created a chunk of size 1875, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1979, which is longer than the specified 1500
# Created a chunk of size 1540, which is longer than the specified 1500
# Created a chunk of size 1819, which is longer than the specified 1500
# Created a chunk of size 2359, which is longer than the specified 1500
# Created a chunk of size 1512, which is longer than the specified 1500
# Created a chunk of size 1540, which is longer than the specified 1500
# Created a chunk of size 1519, which is longer than the specified 1500
# Created a chunk of size 1579, which is longer than the specified 1500
# Created a chunk of size 1899, which is longer than the specified 1500
# Created a chunk of size 1740, which is longer than the specified 1500
# Created a chunk of size 2094, which is longer than the specified 1500
# Created a chunk of size 1580, which is longer than the specified 1500
# Created a chunk of size 2383, which is longer than the specified 1500
# Created a chunk of size 1607, which is longer than the specified 1500
# Created a chunk of size 1772, which is longer than the specified 1500
# Created a chunk of size 1740, which is longer than the specified 1500
# Created a chunk of size 1535, which is longer than the specified 1500
# Created a chunk of size 1544, which is longer than the specified 1500
# Created a chunk of size 1717, which is longer than the specified 1500
# Created a chunk of size 1901, which is longer than the specified 1500
# Created a chunk of size 1604, which is longer than the specified 1500
# Created a chunk of size 1604, which is longer than the specified 1500
# Created a chunk of size 1604, which is longer than the specified 1500
# Created a chunk of size 1511, which is longer than the specified 1500
# Created a chunk of size 1647, which is longer than the specified 1500
# Created a chunk of size 1738, which is longer than the specified 1500
# Created a chunk of size 2232, which is longer than the specified 1500
# Created a chunk of size 1738, which is longer than the specified 1500
# Created a chunk of size 2232, which is longer than the specified 1500
# Created a chunk of size 1779, which is longer than the specified 1500
# Created a chunk of size 1534, which is longer than the specified 1500
# Created a chunk of size 3038, which is longer than the specified 1500
# Created a chunk of size 1662, which is longer than the specified 1500
# Created a chunk of size 1694, which is longer than the specified 1500
# Created a chunk of size 1608, which is longer than the specified 1500
# Created a chunk of size 2152, which is longer than the specified 1500
# Created a chunk of size 3045, which is longer than the specified 1500
# Created a chunk of size 1601, which is longer than the specified 1500
# Created a chunk of size 1729, which is longer than the specified 1500
# Created a chunk of size 1619, which is longer than the specified 1500
# Created a chunk of size 2205, which is longer than the specified 1500
# Created a chunk of size 1513, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1730, which is longer than the specified 1500
# Created a chunk of size 2261, which is longer than the specified 1500
# Created a chunk of size 2412, which is longer than the specified 1500
# Created a chunk of size 1568, which is longer than the specified 1500
# Created a chunk of size 1539, which is longer than the specified 1500
# Created a chunk of size 1797, which is longer than the specified 1500
# Created a chunk of size 1628, which is longer than the specified 1500
# Created a chunk of size 1628, which is longer than the specified 1500
# Created a chunk of size 1531, which is longer than the specified 1500
# Created a chunk of size 1646, which is longer than the specified 1500
# Created a chunk of size 2069, which is longer than the specified 1500
# Created a chunk of size 1900, which is longer than the specified 1500
# Created a chunk of size 1900, which is longer than the specified 1500
# Created a chunk of size 1678, which is longer than the specified 1500
# Created a chunk of size 1610, which is longer than the specified 1500
# Created a chunk of size 2069, which is longer than the specified 1500
# Created a chunk of size 2408, which is longer than the specified 1500
# Created a chunk of size 1888, which is longer than the specified 1500
# Created a chunk of size 1589, which is longer than the specified 1500
# Created a chunk of size 2036, which is longer than the specified 1500
# Created a chunk of size 1509, which is longer than the specified 1500
# Created a chunk of size 1982, which is longer than the specified 1500
# Created a chunk of size 1561, which is longer than the specified 1500
# Created a chunk of size 1813, which is longer than the specified 1500
# Created a chunk of size 1910, which is longer than the specified 1500
# Created a chunk of size 1807, which is longer than the specified 1500
# Created a chunk of size 1770, which is longer than the specified 1500
# Created a chunk of size 1701, which is longer than the specified 1500
# Created a chunk of size 1596, which is longer than the specified 1500
# Created a chunk of size 1614, which is longer than the specified 1500
# Created a chunk of size 2016, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 2160, which is longer than the specified 1500
# Created a chunk of size 1883, which is longer than the specified 1500
# Created a chunk of size 2046, which is longer than the specified 1500
# Created a chunk of size 1804, which is longer than the specified 1500
# Created a chunk of size 1522, which is longer than the specified 1500
# Created a chunk of size 1522, which is longer than the specified 1500
# Created a chunk of size 1770, which is longer than the specified 1500
# Created a chunk of size 1501, which is longer than the specified 1500
# Created a chunk of size 2034, which is longer than the specified 1500
# Created a chunk of size 1815, which is longer than the specified 1500
# Created a chunk of size 1548, which is longer than the specified 1500
# Created a chunk of size 1517, which is longer than the specified 1500
# Created a chunk of size 2244, which is longer than the specified 1500
# Created a chunk of size 2244, which is longer than the specified 1500
# Created a chunk of size 2986, which is longer than the specified 1500
# Created a chunk of size 4256, which is longer than the specified 1500
# Created a chunk of size 1795, which is longer than the specified 1500
# Created a chunk of size 2577, which is longer than the specified 1500
# Created a chunk of size 2188, which is longer than the specified 1500
# Created a chunk of size 2885, which is longer than the specified 1500
# Created a chunk of size 1780, which is longer than the specified 1500
# Created a chunk of size 1650, which is longer than the specified 1500
# Created a chunk of size 1698, which is longer than the specified 1500
# Created a chunk of size 1542, which is longer than the specified 1500
# Created a chunk of size 1689, which is longer than the specified 1500
# Created a chunk of size 1537, which is longer than the specified 1500
# Created a chunk of size 1549, which is longer than the specified 1500
# Created a chunk of size 1685, which is longer than the specified 1500
# Created a chunk of size 1575, which is longer than the specified 1500
# Created a chunk of size 1875, which is longer than the specified 1500
# Created a chunk of size 1814, which is longer than the specified 1500
# Created a chunk of size 2020, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 1934, which is longer than the specified 1500
# Created a chunk of size 1934, which is longer than the specified 1500
# Created a chunk of size 1878, which is longer than the specified 1500
# Created a chunk of size 4220, which is longer than the specified 1500
# Created a chunk of size 2098, which is longer than the specified 1500
# Created a chunk of size 1717, which is longer than the specified 1500
# Created a chunk of size 1599, which is longer than the specified 1500
# Created a chunk of size 1633, which is longer than the specified 1500
# Created a chunk of size 2179, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 2525, which is longer than the specified 1500
# Created a chunk of size 2039, which is longer than the specified 1500
# Created a chunk of size 1859, which is longer than the specified 1500
# Created a chunk of size 1859, which is longer than the specified 1500
# Created a chunk of size 1859, which is longer than the specified 1500
# Created a chunk of size 1859, which is longer than the specified 1500
# Created a chunk of size 1859, which is longer than the specified 1500
# Created a chunk of size 2813, which is longer than the specified 1500
# Created a chunk of size 1840, which is longer than the specified 1500
# Created a chunk of size 2005, which is longer than the specified 1500
# Created a chunk of size 1811, which is longer than the specified 1500
# Created a chunk of size 2956, which is longer than the specified 1500
# Created a chunk of size 1504, which is longer than the specified 1500
# Created a chunk of size 1641, which is longer than the specified 1500
# Created a chunk of size 1542, which is longer than the specified 1500
# Created a chunk of size 2206, which is longer than the specified 1500
# Created a chunk of size 1613, which is longer than the specified 1500
# Created a chunk of size 2617, which is longer than the specified 1500
# Created a chunk of size 1792, which is longer than the specified 1500
# Created a chunk of size 2547, which is longer than the specified 1500
# Created a chunk of size 2582, which is longer than the specified 1500
# Created a chunk of size 2020, which is longer than the specified 1500
# Created a chunk of size 1527, which is longer than the specified 1500
# Created a chunk of size 1626, which is longer than the specified 1500

# %%
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(docs, embeddings)

# %%
db.save_local("data/faiss_index")
